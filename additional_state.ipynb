# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from census import Census

# %%
csv_file = '../green_city/medianHouseholdIncome.csv'
csv_file
# Out:
# '../green_city/medianHouseholdIncome.csv'

# %%
Household_Income_df = pd.read_csv(csv_file)

# %%
Household_Income_df["State / County Name"].value_counts()
# Out:
# Woodford County (IL)           6
# Delaware County (OK)           6
# Scott County (KS)              6
# Palo Pinto County (TX)         6
# Dickens County (TX)            6
#                               ..
# Petersburg Census Area (AK)    4
# Bedford city (VA)              4
# Petersburg Borough (AK)        2
# Oglala Lakota County (SD)      1
# Kusilvak Census Area (AK)      1
# Name: State / County Name, Length: 3198, dtype: int64

# %%
ND_Household_Income_df = Household_Income_df.loc[(Household_Income_df["State"]==38)]
# Out:
#       Year  State  County ID    State / County Name  \
# 84    2015     38      38001      Adams County (ND)
# 85    2014     38      38001      Adams County (ND)
# 86    2013     38      38001      Adams County (ND)
# 87    2012     38      38001      Adams County (ND)
# 88    2011     38      38001      Adams County (ND)
# 89    2010     38      38001      Adams County (ND)
# 822   2015     38      38003     Barnes County (ND)
# 823   2014     38      38003     Barnes County (ND)
# 824   2013     38      38003     Barnes County (ND)
# 825   2012     38      38003     Barnes County (ND)
# 826   2011     38      38003     Barnes County (ND)
# 827   2010     38      38003     Barnes County (ND)
# 1096  2015     38      38005     Benson County (ND)
# 1097  2014     38      38005     Benson County (ND)
# 1098  2013     38      38005     Benson County (ND)
# 1099  2012     38      38005     Benson County (ND)
# 1100  2011     38      38005     Benson County (ND)
# ...

# %%
ND_Household_Income_df["State / County Name"].value_counts(ascending=False)

# %%
#Burlington County is BU
BU_ND_Income_df = ND_Household_Income_df.loc[(ND_Household_Income_df["State / County Name"]=="Burleigh County (ND)")]
BU_ND_Income_df
# Out:
#       Year  State  County ID   State / County Name  \
# 1924  2015     38      38015  Burleigh County (ND)
# 1925  2014     38      38015  Burleigh County (ND)
# 1926  2013     38      38015  Burleigh County (ND)
# 1927  2012     38      38015  Burleigh County (ND)
# 1928  2011     38      38015  Burleigh County (ND)
# 1929  2010     38      38015  Burleigh County (ND)
#
#      All Ages SAIPE Poverty Universe All Ages in Poverty Count  \
# 1924                          89,570                     8,048
# 1925                          86,998                     7,160
# 1926                          85,477                     7,088
# 1927                          82,656                     5,625
# 1928                          80,470                     7,347
# 1929                          79,036                     7,353
#
#      All Ages in Poverty Count LB 90% All Ages in Poverty Count UB 90%  \
# 1924                            6,890                            9,206
# ...

# %%
ND_Household_Income_df = ND_Household_Income_df.drop_duplicates()
ND_Household_Income_df
# Out:
#        Year  State  County ID   State / County Name  \
# 84     2015     38      38001     Adams County (ND)
# 85     2014     38      38001     Adams County (ND)
# 86     2013     38      38001     Adams County (ND)
# 87     2012     38      38001     Adams County (ND)
# 88     2011     38      38001     Adams County (ND)
# ...     ...    ...        ...                   ...
# 18665  2014     38      38105  Williams County (ND)
# 18666  2013     38      38105  Williams County (ND)
# 18667  2012     38      38105  Williams County (ND)
# 18668  2011     38      38105  Williams County (ND)
# 18669  2010     38      38105  Williams County (ND)
#
#       All Ages SAIPE Poverty Universe All Ages in Poverty Count  \
# 84                              2,299                       233
# 85                              2,310                       236
# 86                              2,307                       235
# 87                              2,271                       233
# ...

# %%
BU_ND_Household_Income_df = BU_ND_Income_df.loc[:, ["Year", "State / County Name", "Median Household Income in Dollars"]]
BU_ND_Household_Income_df
# Out:
#       Year   State / County Name Median Household Income in Dollars
# 1924  2015  Burleigh County (ND)                           $66,057
# 1925  2014  Burleigh County (ND)                           $66,734
# 1926  2013  Burleigh County (ND)                           $63,503
# 1927  2012  Burleigh County (ND)                           $62,104
# 1928  2011  Burleigh County (ND)                           $57,519

# %%
BU_ND_Household_Income_df.dropna(how="any")
# Out:
#       Year   State / County Name Median Household Income in Dollars
# 1924  2015  Burleigh County (ND)                           $66,057
# 1925  2014  Burleigh County (ND)                           $66,734
# 1926  2013  Burleigh County (ND)                           $63,503
# 1927  2012  Burleigh County (ND)                           $62,104
# 1928  2011  Burleigh County (ND)                           $57,519
# 1929  2010  Burleigh County (ND)                           $55,565

# %%
BU_ND_Household_Income_df["Median Household Income"] = BU_ND_Household_Income_df["Median Household Income in Dollars"].str.replace('$', '').str.replace(',', '')
BU_ND_Household_Income_df["Median Household Income"] = pd.to_numeric(BU_ND_Household_Income_df["Median Household Income"])
BU_ND_Household_Income_df["Median Household Income"]
# Out:
# 1924    66057
# 1925    66734
# 1926    63503
# 1927    62104
# 1928    57519
# 1929    55565
# Name: Median Household Income, dtype: int64

# %%
BU_ND_Household_Income_df.head()
# Out:
#       Year   State / County Name Median Household Income in Dollars  \
# 1924  2015  Burleigh County (ND)                           $66,057
# 1925  2014  Burleigh County (ND)                           $66,734
# 1926  2013  Burleigh County (ND)                           $63,503
# 1927  2012  Burleigh County (ND)                           $62,104
# 1928  2011  Burleigh County (ND)                           $57,519
#
#       Median Household Income
# 1924                    66057
# 1925                    66734
# 1926                    63503
# 1927                    62104
# 1928                    57519

# %%
#need to fix this
BU_ND_Household_Income_df.describe()
# Out:
#               Year  Median Household Income
# count     6.000000                 6.000000
# mean   2012.500000             61913.666667
# std       1.870829              4529.540713
# min    2010.000000             55565.000000
# 25%    2011.250000             58665.250000
# 50%    2012.500000             62803.500000
# 75%    2013.750000             65418.500000
# max    2015.000000             66734.000000

# %%
BU_ND_Average_HouseHold_income  = BU_ND_Household_Income_df["Median Household Income"].mean()
BU_ND_Average_HouseHold_income
# Out:
# 61913.666666666664
