# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib

import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem

import seaborn as sns

# %%
csv6 = '../Resources/Visu_Income_All_Cities.csv'
Final_Income_Life_mean_df = pd.read_csv(csv6)

# %% [markdown]
# # San Francisco, CA

# %%
SF_Income_Health_df = Final_Income_Life_mean_df.loc[(Final_Income_Life_mean_df["County"]=="Alameda County (CA)") | (Final_Income_Life_mean_df["County"]=="Contra Costa County (CA)") | (Final_Income_Life_mean_df["County"]=="Marin County (CA)") | (Final_Income_Life_mean_df["County"]=="Napa County (CA)") | (Final_Income_Life_mean_df["County"]=="San Francisco County (CA)") | (Final_Income_Life_mean_df["County"]=="San Mateo County (CA)") | (Final_Income_Life_mean_df["County"]=="Santa Clara County (CA)") | (Final_Income_Life_mean_df["County"]=="Solano County (CA)") | (Final_Income_Life_mean_df["County"]=="Sonoma County (CA)")]
SF_Income_Health_df
# Out:
#      State  Year                     County  \
# 84       6  2015        Alameda County (CA)
# 85       6  2014        Alameda County (CA)
# 86       6  2013        Alameda County (CA)
# 87       6  2012        Alameda County (CA)
# 88       6  2011        Alameda County (CA)
# 89       6  2010        Alameda County (CA)
# 90       6  2015   Contra Costa County (CA)
# 91       6  2014   Contra Costa County (CA)
# 92       6  2013   Contra Costa County (CA)
# 93       6  2012   Contra Costa County (CA)
# 94       6  2011   Contra Costa County (CA)
# 95       6  2010   Contra Costa County (CA)
# 96       6  2015          Marin County (CA)
# 97       6  2014          Marin County (CA)
# 98       6  2013          Marin County (CA)
# 99       6  2012          Marin County (CA)
# 100      6  2011          Marin County (CA)
# 101      6  2010          Marin County (CA)
# 102      6  2015           Napa County (CA)
# 103      6  2014           Napa County (CA)
# 104      6  2013           Napa County (CA)
# 105      6  2012           Napa County (CA)
# 106      6  2011           Napa County (CA)
# 107      6  2010           Napa County (CA)
# 108      6  2015  San Francisco County (CA)
# 109      6  2014  San Francisco County (CA)
# 110      6  2013  San Francisco County (CA)
# 111      6  2012  San Francisco County (CA)
# 112      6  2011  San Francisco County (CA)
# 113      6  2010  San Francisco County (CA)
# 114      6  2015      San Mateo County (CA)
# 115      6  2014      San Mateo County (CA)
# 116      6  2013      San Mateo County (CA)
# 117      6  2012      San Mateo County (CA)
# 118      6  2011      San Mateo County (CA)
# 119      6  2010      San Mateo County (CA)
# 120      6  2015    Santa Clara County (CA)
# 121      6  2014    Santa Clara County (CA)
# 122      6  2013    Santa Clara County (CA)
# 123      6  2012    Santa Clara County (CA)
# 124      6  2011    Santa Clara County (CA)
# 125      6  2010    Santa Clara County (CA)
# 126      6  2015         Solano County (CA)
# 127      6  2014         Solano County (CA)
# 128      6  2013         Solano County (CA)
# 129      6  2012         Solano County (CA)
# 130      6  2011         Solano County (CA)
# 131      6  2010         Solano County (CA)
# 132      6  2015         Sonoma County (CA)
# 133      6  2014         Sonoma County (CA)
# 134      6  2013         Sonoma County (CA)
# 135      6  2012         Sonoma County (CA)
# 136      6  2011         Sonoma County (CA)
# 137      6  2010         Sonoma County (CA)
#
#     Median Household Income in Dollars  All Ages in Poverty Percent  \
# 84                            $81,462                          11.5
# 85                            $76,996                          12.5
# 86                            $72,128                          13.0
# 87                            $70,209                          13.1
# 88                            $67,295                          13.2
# 89                            $66,937                          13.5
# 90                            $83,036                          10.2
# 91                            $80,338                          10.5
# 92                            $78,909                          10.8
# 93                            $74,208                          11.1
# 94                            $74,241                          11.9
# 95                            $73,678                           9.3
# 96                            $99,868                           7.5
# 97                            $94,549                           8.8
# 98                            $94,347                           8.7
# 99                            $88,654                           8.5
# 100                           $78,470                           9.4
# 101                           $82,383                           9.2
# 102                           $72,683                          10.1
# 103                           $71,063                           9.0
# 104                           $68,619                           9.7
# 105                           $65,698                           9.7
# 106                           $61,179                          12.0
# 107                           $62,893                          10.7
# 108                           $90,527                          12.4
# 109                           $83,788                          12.1
# 110                           $76,933                          13.8
# 111                           $72,093                          14.9
# 112                           $69,354                          13.8
# 113                           $70,883                          12.8
# 114                          $101,133                           8.4
# 115                          $100,806                           7.5
# 116                           $91,061                           8.0
# 117                           $81,568                           8.4
# 118                           $81,378                           7.9
# 119                           $82,413                           7.0
# 120                          $102,191                           8.3
# 121                           $97,219                           8.5
# 122                           $91,843                          10.5
# 123                           $91,195                          10.8
# 124                           $84,741                          10.7
# 125                           $84,627                          10.6
# 126                           $67,202                          12.0
# 127                           $67,106                          12.3
# 128                           $63,398                          12.9
# 129                           $61,976                          14.2
# 130                           $63,090                          13.6
# 131                           $62,948                          12.2
# 132                           $66,463                          11.0
# 133                           $66,949                          11.3
# 134                           $61,020                          12.4
# 135                           $59,855                          12.1
# 136                           $60,792                          12.2
# 137                           $58,703                          12.8
#
#      Median Household Income
# 84                     81462
# 85                     76996
# 86                     72128
# 87                     70209
# 88                     67295
# 89                     66937
# 90                     83036
# 91                     80338
# 92                     78909
# 93                     74208
# 94                     74241
# 95                     73678
# 96                     99868
# 97                     94549
# 98                     94347
# 99                     88654
# 100                    78470
# 101                    82383
# 102                    72683
# 103                    71063
# 104                    68619
# 105                    65698
# 106                    61179
# 107                    62893
# 108                    90527
# 109                    83788
# 110                    76933
# 111                    72093
# 112                    69354
# 113                    70883
# 114                   101133
# 115                   100806
# 116                    91061
# 117                    81568
# 118                    81378
# 119                    82413
# 120                   102191
# 121                    97219
# 122                    91843
# 123                    91195
# 124                    84741
# 125                    84627
# 126                    67202
# 127                    67106
# 128                    63398
# 129                    61976
# 130                    63090
# 131                    62948
# 132                    66463
# 133                    66949
# 134                    61020
# 135                    59855
# 136                    60792
# 137                    58703

# %% [markdown]
# # Bar Graph _ San Francisco, CA

# %%
SF_County_Poverty_df = SF_Income_Health_df.loc[:, ["County", "All Ages in Poverty Percent"]]
SF_County_Poverty_df.set_index("County", inplace=True)
SF_Pov_df = SF_County_Poverty_df.groupby(["County"])
SF_Pov_df = SF_Pov_df.mean(['All Ages in Poverty Percent'])

SF_Pov_df
# Out:
#                            All Ages in Poverty Percent
# County
# Alameda County (CA)                          12.800000
# Contra Costa County (CA)                     10.633333
# Marin County (CA)                             8.683333
# Napa County (CA)                             10.200000
# San Francisco County (CA)                    13.300000
# San Mateo County (CA)                         7.866667
# Santa Clara County (CA)                       9.900000
# Solano County (CA)                           12.866667
# Sonoma County (CA)                           11.966667

# %%
sort_SF_Pov_df = SF_Pov_df.sort_values (by =["All Ages in Poverty Percent"], axis = 0, ascending=[True])
sort_SF_Pov_df
# Out:
#                            All Ages in Poverty Percent
# County
# San Mateo County (CA)                         7.866667
# Marin County (CA)                             8.683333
# Santa Clara County (CA)                       9.900000
# Napa County (CA)                             10.200000
# Contra Costa County (CA)                     10.633333
# Sonoma County (CA)                           11.966667
# Alameda County (CA)                          12.800000
# Solano County (CA)                           12.866667
# San Francisco County (CA)                    13.300000

# %%
SF_Pov_Chart = sort_SF_Pov_df.plot(kind ="barh", facecolor="green", align="center", alpha=0.5, legend=False)

# Set the xlabel and ylabel using class methods
SF_Pov_Chart.set_xlabel("Percentage Poverty")
SF_Pov_Chart.set_ylabel("County")
SF_Pov_Chart.set_title("Percentage Poverty Vs Counties in San Francisco, CA")
# Out:
# Text(0.5, 1.0, 'Percentage Poverty Vs Counties in San Francisco, CA')

# %%
SF_Pov_Chart.figure.savefig('F:/Final_green_city/green_city/Output/Figures/SF_Percentage_Poverty.png')

# %% [markdown]
# # Baton Rouge, LA

# %%
BR_Income_Health_df = Final_Income_Life_mean_df.loc[(Final_Income_Life_mean_df["County"]=="Ascension Parish (LA)") | (Final_Income_Life_mean_df["County"]=="East Baton Rouge Parish (LA)") | (Final_Income_Life_mean_df["County"]=="East Feliciana Parish (LA)") | (Final_Income_Life_mean_df["County"]=="Iberville Parish (LA)") | (Final_Income_Life_mean_df["County"]=="Livingston Parish (LA)") | (Final_Income_Life_mean_df["County"]=="Pointe Coupee Parish (LA)") | (Final_Income_Life_mean_df["County"]=="St. Helena Parish (LA)") | (Final_Income_Life_mean_df["County"]=="West Baton Rouge Parish (LA)") | (Final_Income_Life_mean_df["County"]=="West Feliciana Parish (LA)")]
BR_Income_Health_df
# Out:
#     State  Year                        County  \
# 30     22  2015         Ascension Parish (LA)
# 31     22  2014         Ascension Parish (LA)
# 32     22  2013         Ascension Parish (LA)
# 33     22  2012         Ascension Parish (LA)
# 34     22  2011         Ascension Parish (LA)
# 35     22  2010         Ascension Parish (LA)
# 36     22  2015  East Baton Rouge Parish (LA)
# 37     22  2014  East Baton Rouge Parish (LA)
# 38     22  2013  East Baton Rouge Parish (LA)
# 39     22  2012  East Baton Rouge Parish (LA)
# 40     22  2011  East Baton Rouge Parish (LA)
# 41     22  2010  East Baton Rouge Parish (LA)
# 42     22  2015    East Feliciana Parish (LA)
# 43     22  2014    East Feliciana Parish (LA)
# 44     22  2013    East Feliciana Parish (LA)
# 45     22  2012    East Feliciana Parish (LA)
# 46     22  2011    East Feliciana Parish (LA)
# 47     22  2010    East Feliciana Parish (LA)
# 48     22  2015         Iberville Parish (LA)
# 49     22  2014         Iberville Parish (LA)
# 50     22  2013         Iberville Parish (LA)
# 51     22  2012         Iberville Parish (LA)
# 52     22  2011         Iberville Parish (LA)
# 53     22  2010         Iberville Parish (LA)
# 54     22  2015        Livingston Parish (LA)
# 55     22  2014        Livingston Parish (LA)
# 56     22  2013        Livingston Parish (LA)
# 57     22  2012        Livingston Parish (LA)
# 58     22  2011        Livingston Parish (LA)
# 59     22  2010        Livingston Parish (LA)
# 60     22  2015     Pointe Coupee Parish (LA)
# 61     22  2014     Pointe Coupee Parish (LA)
# 62     22  2013     Pointe Coupee Parish (LA)
# 63     22  2012     Pointe Coupee Parish (LA)
# 64     22  2011     Pointe Coupee Parish (LA)
# 65     22  2010     Pointe Coupee Parish (LA)
# 66     22  2015        St. Helena Parish (LA)
# 67     22  2014        St. Helena Parish (LA)
# 68     22  2013        St. Helena Parish (LA)
# 69     22  2012        St. Helena Parish (LA)
# 70     22  2011        St. Helena Parish (LA)
# 71     22  2010        St. Helena Parish (LA)
# 72     22  2015  West Baton Rouge Parish (LA)
# 73     22  2014  West Baton Rouge Parish (LA)
# 74     22  2013  West Baton Rouge Parish (LA)
# 75     22  2012  West Baton Rouge Parish (LA)
# 76     22  2011  West Baton Rouge Parish (LA)
# 77     22  2010  West Baton Rouge Parish (LA)
# 78     22  2015    West Feliciana Parish (LA)
# 79     22  2014    West Feliciana Parish (LA)
# 80     22  2013    West Feliciana Parish (LA)
# 81     22  2012    West Feliciana Parish (LA)
# 82     22  2011    West Feliciana Parish (LA)
# 83     22  2010    West Feliciana Parish (LA)
#
#    Median Household Income in Dollars  All Ages in Poverty Percent  \
# 30                           $74,852                          10.7
# 31                           $67,299                          13.7
# 32                           $70,303                          11.1
# 33                           $65,271                          12.1
# 34                           $63,305                          11.5
# 35                           $62,069                          12.8
# 36                           $50,389                          18.5
# 37                           $46,831                          18.4
# 38                           $47,770                          20.8
# 39                           $47,389                          20.5
# 40                           $45,924                          20.2
# 41                           $44,911                          17.3
# 42                           $43,105                          21.8
# 43                           $41,651                          20.4
# 44                           $41,578                          20.6
# 45                           $42,571                          20.8
# 46                           $38,478                          20.7
# 47                           $42,347                          18.6
# 48                           $42,000                          22.3
# 49                           $47,377                          19.9
# 50                           $40,449                          25.7
# 51                           $39,405                          21.3
# 52                           $37,832                          23.0
# 53                           $40,140                          22.7
# 54                           $58,774                          13.5
# 55                           $58,818                          12.3
# 56                           $53,118                          14.3
# 57                           $52,865                          15.2
# 58                           $53,700                          13.2
# 59                           $53,125                          12.5
# 60                           $42,919                          19.3
# 61                           $44,469                          18.3
# 62                           $42,129                          20.2
# 63                           $41,386                          20.8
# 64                           $40,052                          21.9
# 65                           $41,277                          17.6
# 66                           $36,602                          19.9
# 67                           $35,004                          24.0
# 68                           $34,229                          25.8
# 69                           $33,879                          23.7
# 70                           $33,721                          25.0
# 71                           $32,936                          23.9
# 72                           $55,074                          15.1
# 73                           $51,550                          20.5
# 74                           $48,848                          16.4
# 75                           $47,301                          17.2
# 76                           $46,155                          15.6
# 77                           $46,783                          15.0
# 78                           $56,680                          23.9
# 79                           $53,679                          24.0
# 80                           $52,626                          24.4
# 81                           $50,802                          26.4
# 82                           $49,479                          22.6
# 83                           $48,917                          20.9
#
#     Median Household Income
# 30                    74852
# 31                    67299
# 32                    70303
# 33                    65271
# 34                    63305
# 35                    62069
# 36                    50389
# 37                    46831
# 38                    47770
# 39                    47389
# 40                    45924
# 41                    44911
# 42                    43105
# 43                    41651
# 44                    41578
# 45                    42571
# 46                    38478
# 47                    42347
# 48                    42000
# 49                    47377
# 50                    40449
# 51                    39405
# 52                    37832
# 53                    40140
# 54                    58774
# 55                    58818
# 56                    53118
# 57                    52865
# 58                    53700
# 59                    53125
# 60                    42919
# 61                    44469
# 62                    42129
# 63                    41386
# 64                    40052
# 65                    41277
# 66                    36602
# 67                    35004
# 68                    34229
# 69                    33879
# 70                    33721
# 71                    32936
# 72                    55074
# 73                    51550
# 74                    48848
# 75                    47301
# 76                    46155
# 77                    46783
# 78                    56680
# 79                    53679
# 80                    52626
# 81                    50802
# 82                    49479
# 83                    48917

# %% [markdown]
# # Bar Graph _Baton Rouge, LA

# %%
BR_County_Poverty_df = BR_Income_Health_df.loc[:, ["County", "All Ages in Poverty Percent"]]
BR_County_Poverty_df.set_index("County", inplace=True)
BR_Pov_df = BR_County_Poverty_df.groupby(["County"])
BR_Pov_df = BR_Pov_df.mean(['All Ages in Poverty Percent'])

BR_Pov_df
# Out:
#                               All Ages in Poverty Percent
# County
# Ascension Parish (LA)                           11.983333
# East Baton Rouge Parish (LA)                    19.283333
# East Feliciana Parish (LA)                      20.483333
# Iberville Parish (LA)                           22.483333
# Livingston Parish (LA)                          13.500000
# Pointe Coupee Parish (LA)                       19.683333
# St. Helena Parish (LA)                          23.716667
# West Baton Rouge Parish (LA)                    16.633333
# West Feliciana Parish (LA)                      23.700000

# %%
sort_BR_Pov_df = BR_Pov_df.sort_values (by =["All Ages in Poverty Percent"], axis = 0, ascending=[True])
sort_BR_Pov_df
# Out:
#                               All Ages in Poverty Percent
# County
# Ascension Parish (LA)                           11.983333
# Livingston Parish (LA)                          13.500000
# West Baton Rouge Parish (LA)                    16.633333
# East Baton Rouge Parish (LA)                    19.283333
# Pointe Coupee Parish (LA)                       19.683333
# East Feliciana Parish (LA)                      20.483333
# Iberville Parish (LA)                           22.483333
# West Feliciana Parish (LA)                      23.700000
# St. Helena Parish (LA)                          23.716667

# %%
BR_Pov_Chart = sort_BR_Pov_df.plot(kind ="barh", facecolor="orange", align="center", alpha=0.5, legend=False)

# Set the xlabel and ylabel using class methods
BR_Pov_Chart.set_xlabel("Percentage Poverty")
BR_Pov_Chart.set_ylabel("County")
BR_Pov_Chart.set_title("Percentage Poverty Vs Counties in Baton Rouge, LA")
# Out:
# Text(0.5, 1.0, 'Percentage Poverty Vs Counties in Baton Rouge, LA')

# %%
BR_Pov_Chart.figure.savefig('F:/Final_green_city/green_city/Output/Figures/BR_Percentage_Poverty.png')

# %% [markdown]
# # Pittsburgh, PA

# %%
PIT_Income_Health_df = Final_Income_Life_mean_df.loc[(Final_Income_Life_mean_df["County"]=="Allegheny County (PA)") | (Final_Income_Life_mean_df["County"]=="Beaver County (PA)") | (Final_Income_Life_mean_df["County"]=="Butler County (PA)") | (Final_Income_Life_mean_df["County"]=="Washington County (PA)") | (Final_Income_Life_mean_df["County"]=="Westmoreland County (PA)")]
PIT_Income_Health_df
# Out:
#     State  Year                    County Median Household Income in Dollars  \
# 0      42  2015     Allegheny County (PA)                           $54,412
# 1      42  2014     Allegheny County (PA)                           $52,385
# 2      42  2013     Allegheny County (PA)                           $51,400
# 3      42  2012     Allegheny County (PA)                           $50,831
# 4      42  2011     Allegheny County (PA)                           $49,682
# 5      42  2010     Allegheny County (PA)                           $47,490
# 6      42  2015        Beaver County (PA)                           $50,131
# 7      42  2014        Beaver County (PA)                           $51,041
# 8      42  2013        Beaver County (PA)                           $49,215
# 9      42  2012        Beaver County (PA)                           $46,933
# 10     42  2011        Beaver County (PA)                           $48,140
# 11     42  2010        Beaver County (PA)                           $44,020
# 12     42  2015        Butler County (PA)                           $67,892
# 13     42  2014        Butler County (PA)                           $60,851
# 14     42  2013        Butler County (PA)                           $58,430
# 15     42  2012        Butler County (PA)                           $57,346
# 16     42  2011        Butler County (PA)                           $54,888
# 17     42  2010        Butler County (PA)                           $54,363
# 18     42  2015    Washington County (PA)                           $57,622
# 19     42  2014    Washington County (PA)                           $55,796
# 20     42  2013    Washington County (PA)                           $54,919
# 21     42  2012    Washington County (PA)                           $53,545
# 22     42  2011    Washington County (PA)                           $52,384
# 23     42  2010    Washington County (PA)                           $47,823
# 24     42  2015  Westmoreland County (PA)                           $53,422
# 25     42  2014  Westmoreland County (PA)                           $53,536
# 26     42  2013  Westmoreland County (PA)                           $51,412
# 27     42  2012  Westmoreland County (PA)                           $49,642
# 28     42  2011  Westmoreland County (PA)                           $46,630
# 29     42  2010  Westmoreland County (PA)                           $46,468
#
#     All Ages in Poverty Percent  Median Household Income
# 0                          12.2                    54412
# 1                          13.1                    52385
# 2                          13.5                    51400
# 3                          12.7                    50831
# 4                          13.4                    49682
# 5                          11.9                    47490
# 6                          13.1                    50131
# 7                          11.7                    51041
# 8                          11.3                    49215
# 9                          12.0                    46933
# 10                         12.3                    48140
# 11                         15.1                    44020
# 12                          9.5                    67892
# 13                          8.9                    60851
# 14                          9.4                    58430
# 15                          9.6                    57346
# 16                          8.9                    54888
# 17                          9.3                    54363
# 18                         10.1                    57622
# 19                         10.7                    55796
# 20                         10.9                    54919
# 21                         10.8                    53545
# 22                         10.6                    52384
# 23                         10.6                    47823
# 24                         11.3                    53422
# 25                         10.1                    53536
# 26                         10.7                    51412
# 27                         10.9                    49642
# 28                         10.6                    46630
# 29                         10.4                    46468

# %% [markdown]
# # Bar Graph _Pittsburgh, PA

# %%
PIT_County_Poverty_df = PIT_Income_Health_df.loc[:, ["County", "All Ages in Poverty Percent"]]
PIT_County_Poverty_df.set_index("County", inplace=True)
PIT_Pov_df = PIT_County_Poverty_df.groupby(["County"])
PIT_Pov_df = PIT_Pov_df.mean(['All Ages in Poverty Percent'])

PIT_Pov_df
# Out:
#                           All Ages in Poverty Percent
# County
# Allegheny County (PA)                       12.800000
# Beaver County (PA)                          12.583333
# Butler County (PA)                           9.266667
# Washington County (PA)                      10.616667
# Westmoreland County (PA)                    10.666667

# %%
sort_PIT_Pov_df = PIT_Pov_df.sort_values (by =["All Ages in Poverty Percent"], axis = 0, ascending=[True])
sort_PIT_Pov_df
# Out:
#                           All Ages in Poverty Percent
# County
# Butler County (PA)                           9.266667
# Washington County (PA)                      10.616667
# Westmoreland County (PA)                    10.666667
# Beaver County (PA)                          12.583333
# Allegheny County (PA)                       12.800000

# %%
PIT_Pov_Chart = sort_PIT_Pov_df.plot(kind ="barh", facecolor="blue", align="center", alpha=0.4, legend=False)

# Set the xlabel and ylabel using class methods
PIT_Pov_Chart.set_xlabel("Percentage Poverty")
PIT_Pov_Chart.set_ylabel("County")
PIT_Pov_Chart.set_title("Percentage Poverty Vs Counties in Pittsburg, PA")
# Out:
# Text(0.5, 1.0, 'Percentage Poverty Vs Counties in Pittsburg, PA')

# %%
PIT_Pov_Chart.figure.savefig('F:/Final_green_city/green_city/Output/Figures/PIT_Percentage_Poverty.png')

# %% [markdown]
# # Comparison of SF , BR and PIT

# %%
Country_Poverty_df = Final_Income_Life_mean_df.loc[:, ["State", "All Ages in Poverty Percent"]]

Country_Poverty_df.loc[Country_Poverty_df['State'] == 42, 'State'] = 'Pennsylvania'
Country_Poverty_df.loc[Country_Poverty_df['State'] == 22, 'State'] = 'Louisiana'
Country_Poverty_df.loc[Country_Poverty_df['State'] == 6, 'State'] = 'California'

Country_Poverty_df
# Out:
#             State  All Ages in Poverty Percent
# 0    Pennsylvania                         12.2
# 1    Pennsylvania                         13.1
# 2    Pennsylvania                         13.5
# 3    Pennsylvania                         12.7
# 4    Pennsylvania                         13.4
# ..            ...                          ...
# 133    California                         11.3
# 134    California                         12.4
# 135    California                         12.1
# 136    California                         12.2
# 137    California                         12.8
#
# [138 rows x 2 columns]

# %%
ax = sns.boxplot(x="State", y="All Ages in Poverty Percent", data=Country_Poverty_df, palette="Set2")

ax.set_title('Percentage Poverty of Cities for Year 2010 to 2015')
ax.set_ylabel('Percentage Poverty')
ax.set_xlabel('San Francisco                Baton Rouge             Pittsburgh')

PercentPoverty = Country_Poverty_df["All Ages in Poverty Percent"]

quartiles = PercentPoverty.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of Percentage Poverty is: {lowerq}")
print(f"The upper quartile of Percentage Poverty is: {upperq}")
print(f"The interquartile range of Percentage Poverty is: {iqr}")
print(f"The the median of Life Expectancy is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Percentage Poverty is: 10.625
# The upper quartile of Percentage Poverty is: 18.125
# The interquartile range of Percentage Poverty is: 7.5
# The the median of Life Expectancy is: 12.4
# Values below -0.625 could be outliers.
# Values above 29.375 could be outliers.

# %%
ax.figure.savefig('F:/Final_green_city/green_city/Output/Figures/Percentage_Poverty.png')
