# %%
# %matplotlib notebook

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import matplotlib.colors as mcolors

# %%
csv_file = 'Pitt_Median_Income.csv'
csv_file
# Out:
# 'Pitt_Median_Income.csv'

# %%
Pitt_Median_Income_df = pd.read_csv(csv_file)
Pitt_Median_Income_df
# Out:
#         State / County Name  Median Household Income
# 0     Allegheny County (PA)             51033.333333
# 1        Beaver County (PA)             48246.666667
# 2        Butler County (PA)             58961.666667
# 3    Washington County (PA)             53681.500000
# 4  Westmoreland County (PA)             50185.000000

# %%
# Create the X and Y axis lists
years = np.arange(0,2016,1)
county = [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
railgun_speeds = [75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]

# %%
#create bar chart showing median hh income comparison between Baton Rouge, Pittsburgh, San Francisco 
cities = ["San Francisco", "Pittsburgh", "Baton Rouge", "U.S."]
median_hh_income = [76909, 52421, 51954, 47780]
x_axis = cities

# %%
# Give our chart some labels and a tile
plt.title("Median Household Income")
plt.xlabel("Cities")
plt.ylabel("Income")
# Out:
# Text(25.902777777777786, 0.5, 'Income')

# %%
# Change the bar colors here
#plt.bar(labels, values, color=['red', 'blue', 'purple', 'green', 'lavender'])

# %%
#Create a bar chart based upon the above data
plt.bar(x_axis, median_hh_income, color=['forestgreen', 'silver', 'darkseagreen', 'navy'], align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 4 artists>
